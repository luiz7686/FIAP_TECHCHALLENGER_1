# %% [markdown]
# Importa dependencias

# %%
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

# %% [markdown]
# Importa arquivo de Vinhos

# %%
path= r"C:\Users\luiz7\Documents\PosTech\TECHCHALLENGER_1"
df = pd.read_csv(path+r"\FILES\content\ExpVinho.csv", sep=';')
df=df.set_index(['País'])
df.drop(columns='Id', inplace=True)
display(df.head(5))
# Out:
#                                  1970  1970.1  1971  1971.1  1972  1972.1  \
# País
# Afeganistão                         0       0     0       0     0       0
# África do Sul                       0       0     0       0     0       0
# Alemanha, República Democrática     0       0     0       0  4168    2630
# Angola                              0       0     0       0     0       0
# Anguilla                            0       0     0       0     0       0
#
#                                   1973  1973.1  1974  1974.1  ...   2017  \
# País                                                          ...
# Afeganistão                          0       0     0       0  ...      0
# África do Sul                        0       0     0       0  ...      0
# Alemanha, República Democrática  12000    8250     0       0  ...  15467
# Angola                               0       0     0       0  ...  10170
# Anguilla                             0       0     0       0  ...      0
#
# ...

# %%
df.drop('Brasil', inplace=True)

# %%
df.head(5)
# Out:
#                                  1970  1970.1  1971  1971.1  1972  1972.1  \
# País
# Afeganistão                         0       0     0       0     0       0
# África do Sul                       0       0     0       0     0       0
# Alemanha, República Democrática     0       0     0       0  4168    2630
# Angola                              0       0     0       0     0       0
# Anguilla                            0       0     0       0     0       0
#
#                                   1973  1973.1  1974  1974.1  ...   2017  \
# País                                                          ...
# Afeganistão                          0       0     0       0  ...      0
# África do Sul                        0       0     0       0  ...      0
# Alemanha, República Democrática  12000    8250     0       0  ...  15467
# Angola                               0       0     0       0  ...  10170
# Anguilla                             0       0     0       0  ...      0
#
# ...

# %%
ano_analise = df.columns[76:]
df = df[ano_analise]
df
# Out:
#                                    2008  2008.1    2009  2009.1   2010  \
# País
# Afeganistão                           0       0       0       0      0
# África do Sul                         0       0       0       0      0
# Alemanha, República Democrática  265742  429970  225086  393482  27715
# Angola                            25721   71083   54786   84235  33557
# Anguilla                              0       0       0       0      0
# ...                                 ...     ...     ...     ...    ...
# Tuvalu                                0       0       0       0      0
# Uruguai                               0       0       0       0    914
# Vanuatu                               0       0       0       0      0
# Venezuela                             0       0       0       0      0
# Vietnã                                0       0     743    2143   8820
#
#                                  2010.1   2011  2011.1  2012  2012.1  ...  \
# ...

# %% [markdown]
# Cria dataFrames separados para quantidade e valor (cabecario duplica)

# %%
df=df.rename(columns=lambda c: c[:4]+"$" if c[4:] == '.1' else c)

# %%
df
# Out:
#                                    2008   2008$    2009   2009$   2010  \
# País
# Afeganistão                           0       0       0       0      0
# África do Sul                         0       0       0       0      0
# Alemanha, República Democrática  265742  429970  225086  393482  27715
# Angola                            25721   71083   54786   84235  33557
# Anguilla                              0       0       0       0      0
# ...                                 ...     ...     ...     ...    ...
# Tuvalu                                0       0       0       0      0
# Uruguai                               0       0       0       0    914
# Vanuatu                               0       0       0       0      0
# Venezuela                             0       0       0       0      0
# Vietnã                                0       0     743    2143   8820
#
#                                   2010$   2011   2011$  2012  2012$  ...  \
# ...

# %%
columns_valor = [col for col in df.columns if '$' in col]
columns_qtd = [col for col in df.columns if '$' not in  col]
df_valor = df[columns_valor]
df_volume = df[columns_qtd]

# %%
df_valor['Total$'] = df_valor.sum(axis=1)
# Out:
# C:\Users\luiz7\AppData\Local\Temp\ipykernel_15540\4083182781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valor['Total$'] = df_valor.sum(axis=1)

# %%
df_valor.loc['total']= df_valor.sum() 
df_valor
# Out:
# C:\Users\luiz7\AppData\Local\Temp\ipykernel_15540\2542579347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valor.loc['total']= df_valor.sum()
#                                    2008$    2009$    2010$    2011$    2012$  \
# País
# Afeganistão                            0        0        0        0        0
# África do Sul                          0        0        0        0        0
# Alemanha, República Democrática   429970   393482   138666   144150    56342
# Angola                             71083    84235   189891    69001     8861
# Anguilla                               0        0        0        0        0
# ...                                  ...      ...      ...      ...      ...
# Uruguai                                0        0     2929     4404     3879
# ...

# %%
df_volume['Total'] = df_volume.sum(axis=1)
df_volume.loc['total']= df_volume.sum() 
df_volume
# Out:
# C:\Users\luiz7\AppData\Local\Temp\ipykernel_15540\4148745195.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_volume['Total'] = df_volume.sum(axis=1)
# C:\Users\luiz7\AppData\Local\Temp\ipykernel_15540\4148745195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_volume.loc['total']= df_volume.sum()
#                                      2008      2009     2010     2011  \
# País
# Afeganistão                             0         0        0        0
# África do Sul                           0         0        0        0
# ...

# %%
df_valor=df_valor.rename(columns=lambda c: c.replace('$',''))
df_valor
# Out:
#                                     2008     2009     2010     2011     2012  \
# País
# Afeganistão                            0        0        0        0        0
# África do Sul                          0        0        0        0        0
# Alemanha, República Democrática   429970   393482   138666   144150    56342
# Angola                             71083    84235   189891    69001     8861
# Anguilla                               0        0        0        0        0
# ...                                  ...      ...      ...      ...      ...
# Uruguai                                0        0     2929     4404     3879
# Vanuatu                                0        0        0        0        0
# Venezuela                              0        0        0        0     7492
# Vietnã                                 0     2143     9977        0        0
# total                            7118100  8940988  2595303  3615120  5521293
#
# ...

# %%
linha1 = df_valor.loc['total']
linha2 = df_volume.loc['total']
resultado = linha1/linha2
df_resultado = pd.DataFrame(resultado)

# %%
df_resultado.T.head(15)
# Out:
#            2008      2009      2010      2011      2012      2013      2014  \
# total  0.687984  0.350432  2.026672  2.975814  0.956006  2.486031  3.215448
#
#            2015      2016      2017      2018      2019      2020      2021  \
# total  2.310562  2.482274  2.469434  1.941325  1.882355  1.378385  1.222521
#
#           Total
# total  1.256219

# %% [markdown]
# # construir  tabela contendo:
# a.Pais de Origem (Brazil)\
# b.País de destino\
# c.Quantidade em litros de vinho exportado (1kg=1 litro)\
# d.Valor em US$
